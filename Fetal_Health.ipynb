# %% [markdown]
# ## Fetal Health Classification

# %% [markdown]
# ### Data wrangling

# %%
#Import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from warnings import filterwarnings

# %%
#Load data
fetal_data = pd.read_csv('data/fetal_health.csv')

# %%
# Call info() on data 
fetal_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 22 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   baseline value                                          2126 non-null   float64
#  1   accelerations                                           2126 non-null   float64
#  2   fetal_movement                                          2126 non-null   float64
#  3   uterine_contractions                                    2126 non-null   float64
#  4   light_decelerations                                     2126 non-null   float64
#  5   severe_decelerations                                    2126 non-null   float64
#  6   prolongued_decelerations                                2126 non-null   float64
#  7   abnormal_short_term_variability                         2126 non-null   float64
# ...

# %%
# Call head() on data 
fetal_data.head()
# Out:
#    baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0           120.0          0.000             0.0                 0.000
# 1           132.0          0.006             0.0                 0.006
# 2           133.0          0.003             0.0                 0.008
# 3           134.0          0.003             0.0                 0.008
# 4           132.0          0.007             0.0                 0.008
#
#    light_decelerations  severe_decelerations  prolongued_decelerations  \
# 0                0.000                   0.0                       0.0
# 1                0.003                   0.0                       0.0
# 2                0.003                   0.0                       0.0
# 3                0.003                   0.0                       0.0
# 4                0.000                   0.0                       0.0
#
#    abnormal_short_term_variability  mean_value_of_short_term_variability  \
# ...

# %%
#Call shape on data
fetal_data.shape
# Out:
# (2126, 22)

# %%
#Check if there is any null values
fetal_data.isnull().sum()
# Out:
# baseline value                                            0
# accelerations                                             0
# fetal_movement                                            0
# uterine_contractions                                      0
# light_decelerations                                       0
# severe_decelerations                                      0
# prolongued_decelerations                                  0
# abnormal_short_term_variability                           0
# mean_value_of_short_term_variability                      0
# percentage_of_time_with_abnormal_long_term_variability    0
# mean_value_of_long_term_variability                       0
# histogram_width                                           0
# histogram_min                                             0
# histogram_max                                             0
# histogram_number_of_peaks                                 0
# histogram_number_of_zeroes                                0
# ...

# %%
# Call describe() on data to get the relevant summary statistics for data 
fetal_data.describe()
# Out:
#        baseline value  accelerations  fetal_movement  uterine_contractions  \
# count     2126.000000    2126.000000     2126.000000           2126.000000
# mean       133.303857       0.003178        0.009481              0.004366
# std          9.840844       0.003866        0.046666              0.002946
# min        106.000000       0.000000        0.000000              0.000000
# 25%        126.000000       0.000000        0.000000              0.002000
# 50%        133.000000       0.002000        0.000000              0.004000
# 75%        140.000000       0.006000        0.003000              0.007000
# max        160.000000       0.019000        0.481000              0.015000
#
#        light_decelerations  severe_decelerations  prolongued_decelerations  \
# count          2126.000000           2126.000000               2126.000000
# mean              0.001889              0.000003                  0.000159
# ...

# %% [markdown]
# ### EDA

# %%
#Checking class impalancing 

sns.countplot(x ="fetal_health", data = fetal_data)
plt.show()

# %%
#Counts of response variable values
fetal_data.fetal_health.value_counts()
# Out:
# 1.0    1655
# 2.0     295
# 3.0     176
# Name: fetal_health, dtype: int64

# %%
#Percentage of variable values and plot
total = fetal_data['fetal_health'].value_counts().sum()
normal = total - 471
suspect = total - 1831
pathological = total - 1950

fig = plt.pie([normal, suspect, pathological], labels = ['Normal', 'Suspect', 'Pathological'], colors = ['#F39C12', '#BA4A00', '#935116'], explode=[0.01,0.01,0.01], autopct="%1.0f%%")
plt.title('Pie chart of Fetal Heath', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Pie chart of Fetal Heath')

# %%
plt.figure(figsize=(25,25))
i=1
for col in fetal_data.columns:
    plt.subplot(6,4,i)
    sns.boxplot(x = 'fetal_health', y = col, data = fetal_data)
    plt.tight_layout()
    plt.title(col,fontsize=18)
    i+=1

# %% [markdown]
# #### Most of the box plots show that Normal and Suspect are highly overlapping

# %% [markdown]
# ### Correlation

# %%
plt.figure(figsize=(15,15))
sns.heatmap(fetal_data.corr(), square="True", annot=True, cmap= "coolwarm")
plt.show()

# %% [markdown]
# Based on the correlation matix, it is clear that "prolongued_decelerations", "abnormal_short_term_variability", "percentage_of_time_with_abnormal_long_term_variability" are the features with higher correlation with fetal_health.

# %%
#Map values {1.0, 2.0, 3.0} to {'Normal', Suspect', 'Pathological'}
fetal_data['fetal_health'] = fetal_data['fetal_health'].map({1:'Normal', 2:'Suspect', 3:'Pathological'})

# %%
def plot_category(feature, figsize=None):
    Normal_count = fetal_data[fetal_data['fetal_health']=='Normal'].groupby([feature]).size()
    Suspect_count = fetal_data[fetal_data['fetal_health']=='Suspect'].groupby([feature]).size()
    Pathological_count = fetal_data[fetal_data['fetal_health']=='Pathological'].groupby([feature]).size()
    labels = Normal_count.index

    x = np.arange(len(labels)) # the label locations
    width = 0.7  # the width of the bars

    if figsize:
        fig, ax = plt.subplots(figsize=figsize)
    else:
        fig, ax = plt.subplots()
    rects1 = ax.bar(x-width/3, round(Normal_count*100/fetal_data.groupby([feature]).size(), 2), 
                    width/5, label='Normal')
    rects2 = ax.bar(x-width/8, round(Suspect_count*100/fetal_data.groupby([feature]).size(), 2), 
                    width/5, label='Suspect')
    rects3 = ax.bar(x+width/8, round(Pathological_count*100/fetal_data.groupby([feature]).size(), 2), 
                    width/5, label='Pathological')
    ax.set_ylabel('Count')
    ax.set_title('Based on %s'%feature)
    ax.set_xticks(x)
    ax.set_xticklabels(labels, rotation=80)
    ax.legend(loc=0, bbox_to_anchor=(1, 1));
    
    ax.bar_label(rects1, padding=1)
    ax.bar_label(rects2, padding=1)
    ax.bar_label(rects3, padding=1)
    ax.bar_label(rects4, padding=1)

    fig.tight_layout()
    plt.show()
    
def plot_numerical(feature, figsize=None):
    fig = plt.figure(figsize=(10,6))
    
    
    sns.kdeplot(fetal_data[fetal_data['fetal_health']=='Normal'][feature])
    sns.kdeplot(fetal_data[fetal_data['fetal_health']=='Suspect'][feature])
    sns.kdeplot(fetal_data[fetal_data['fetal_health']=='Pathological'][feature])

    fig.legend(labels=['Normal', 'Suspect', 'Pathological'])
    plt.title('fetal_health based on %s'%feature)
    plt.show()
    
def plot_pie(feature):
    plot_data = fetal_data.groupby([feature, 'fetal_health'])[feature].agg({'count'}).reset_index()
    
    fig = px.sunburst(plot_data, path = [feature, 'fetal_health'], values = 'count', color = feature, 
                      title = 'Affect of %s on Customer fetal_health'%feature, width = 600, height = 600)

    fig.update_layout(plot_bgcolor = 'white', title_font_family = 'Calibri Black', title_font_color = '#221f1f', 
                      title_font_size = 22, title_x = 0.5)

    fig.update_traces(textinfo = 'label + percent parent')
    fig.show()

# %%
for feature in ['uterine_contractions', 'baseline value', 'fetal_movement']:
    plot_numerical(feature)

# %% [markdown]
# #### As we see above:
# Fetal is Normal when uterine_contractions is > 0.0025 and Suspect when uterine_contractions is < 0.0025
#
# Fetal is Pathological when baseline value is between 125-135 and Suspect when baseline value is 135+
#
# Fetal is Suspect when fetal_movement is < 0.03 and Pathological when fetal_movement is between 0.3-0.38

# %%
for feature in ['abnormal_short_term_variability', 'mean_value_of_short_term_variability', 
                'percentage_of_time_with_abnormal_long_term_variability',
                'mean_value_of_long_term_variability']:
    plot_numerical(feature)

# %% [markdown]
# #### As we see above:
#
# Fetal is Normal when abnormal_short_term_variability is <50
#
# Fetal is Suspect when mean_value_of_short_term_variability <0.8, 0.8-2 is Normal and >2 is Pathological
#
# Fetal is Normal when percentage_of_time_with_abnormal_long_term_variability between (-8)-8, 8-68 is Suspect and <-8 & >68 is Pathological
#
# Fetal is Pathological when mean_value_of_long_term_variability <3 , 3-10 is Suspect and 10+ is Normal

# %%
for feature in ['histogram_width',
       'histogram_min', 'histogram_max', 'histogram_number_of_peaks', 'histogram_mode', 'histogram_mean',
       'histogram_median', 'histogram_variance', 'histogram_tendency']:
    
    plot_numerical(feature)

# %% [markdown]
# #### As we see above:
#
# The Fetal is Suspect when histogram_variance (-5)-5

# %%
#Checking outliers in the data
plt.figure(figsize=(20,10))
sns.boxplot(data = fetal_data,palette = "Set1")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The above plot shows the range of our feature attributes. All the features are in different ranges. To fit this in a model we must scale it to the same range.

# %% [markdown]
# ## Classification Models

# %% [markdown]
# ### Training Models

# %%
#Define X and y from the data
X = fetal_data.drop('fetal_health', axis=1)
y = fetal_data.fetal_health

# %%
#scale data
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
import numpy as np
scaler = preprocessing.StandardScaler()
X_scaled = scaler.fit_transform(X)
col_names = list(X.columns)
X_scaled = pd.DataFrame(X_scaled, columns=col_names)

# %%
#Checking outliers in the data
plt.figure(figsize=(20,10))
sns.boxplot(data = X_scaled,palette = "Set1")
plt.xticks(rotation=90)
plt.show()

# %%
#Create a 70/30 train and test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=.3, random_state=1)

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import auc
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix,roc_curve,roc_auc_score
from sklearn.metrics import accuracy_score,log_loss
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import classification_report

# %%
lr = LogisticRegression(max_iter=1000)
model_lr= lr.fit(X_train, y_train)
y_pred = model_lr.predict(X_test)

# %%
#Model evaluation

f1 = f1_score(y_test, y_pred, average='weighted')
ac = accuracy_score(y_test, y_pred, normalize=True)
recall = recall_score(y_test, y_pred, average="weighted")
precision = precision_score(y_test, y_pred, average="weighted")

print("********* Linear Regression Results *********")
print("Accuracy    : ", ac)
print("Recall      : ", recall)
print("Precision   : ", precision)
print("F1 Score    : ", f1)
# Out:
# ********* Linear Regression Results *********
# Accuracy    :  0.9012539184952978
# Recall      :  0.9012539184952978
# Precision   :  0.8991875327830675
# F1 Score    :  0.8993347489334438

# %% [markdown]
# #### Classification Report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.94      0.97      0.95       490
# Pathological       0.88      0.71      0.79        52
#      Suspect       0.70      0.68      0.69        96
#
#     accuracy                           0.90       638
#    macro avg       0.84      0.78      0.81       638
# weighted avg       0.90      0.90      0.90       638

# %% [markdown]
# #### Confusion Matrix

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[473   0  17]
#  [  4  37  11]
#  [ 26   5  65]]

# %%
ax= plt.subplot()
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, ax = ax, cmap = "BuPu");

# labels, title and ticks
ax.set_xlabel("Predicted labels")
ax.set_ylabel("True labels")
ax.set_title("Confusion Matrix")
ax.xaxis.set_ticklabels(["Normal", "Suspect", "Pathological"])
# Out:
# [Text(0.5, 0, 'Normal'), Text(1.5, 0, 'Suspect'), Text(2.5, 0, 'Pathological')]

# %% [markdown]
# ## Fit Random Forest Classifier

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

clf = RandomForestClassifier(n_estimators=2126, random_state = 1,n_jobs=-1)
model_clf = clf.fit(X_train, y_train)
y_pred_clf = model_clf.predict(X_test)


#Model evaluation

f1 = f1_score(y_test, y_pred_clf, average='weighted')
ac = accuracy_score(y_test, y_pred_clf, normalize=True)
recall = recall_score(y_test, y_pred_clf, average="weighted")
precision = precision_score(y_test, y_pred_clf, average="weighted")

print("********* Random Forest Results *********")
print("Accuracy    : ", ac)
print("Recall      : ", recall)
print("Precision   : ", precision)
print("F1 Score    : ", f1)
# Out:
# ********* Random Forest Results *********
# Accuracy    :  0.9373040752351097
# Recall      :  0.9373040752351097
# Precision   :  0.9350496923723929
# F1 Score    :  0.9342095635688041

# %% [markdown]
# #### Find the best paramaters using GridSearchCV

# %%
#Grid Search for RainForest Classifier
parameters = {
    'n_estimators' : [100,150,200,500,700,900],
    'max_features' : ['auto', 'sqrt', 'log2'],
    'max_depth' : [4,6,8,12,14,16],
    'criterion' : ['gini', 'entropy'],
    'n_jobs' : [-1,1,None]
}

clf_cv = GridSearchCV(estimator=RandomForestClassifier(), param_grid=parameters, cv= 5)

# Model and fit
model= clf_cv.fit(X_train, y_train)
y_pred_cv = model.predict(X_test)

# %%
#Best score and best parameter for n_neighbors
print("Best Score:" + str(clf_cv.best_score_))
print("Best Parameters: " + str(clf_cv.best_params_))
# Out:
# Best Score:0.949592118048494
# Best Parameters: {'criterion': 'entropy', 'max_depth': 12, 'max_features': 'log2', 'n_estimators': 700, 'n_jobs': None}

# %%
#Fit and score the best number of neighbors
RF_model = RandomForestClassifier(**clf_cv.best_params_)
RF_model.fit(X_train, y_train)
predictions = RF_model.predict(X_test)

# %%
#Model evaluation
f1 = f1_score(y_test, predictions, average='weighted')
ac = accuracy_score(y_test, predictions, normalize=True)
recall = recall_score(y_test, predictions, average="weighted")
precision = precision_score(y_test, predictions, average="weighted")

print("********* Random Forest with GridSearch Results *********")
print("Accuracy    : ", ac)
print("Recall      : ", recall)
print("Precision   : ", precision)
print("F1 Score    : ", f1)
# Out:
# ********* Random Forest with GridSearch Results *********
# Accuracy    :  0.932601880877743
# Recall      :  0.932601880877743
# Precision   :  0.930259022692456
# F1 Score    :  0.9283964641780675

# %% [markdown]
# #### Classification Report

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.94      1.00      0.97       490
# Pathological       0.93      0.83      0.88        52
#      Suspect       0.88      0.67      0.76        96
#
#     accuracy                           0.93       638
#    macro avg       0.92      0.83      0.87       638
# weighted avg       0.93      0.93      0.93       638

# %% [markdown]
# #### Confusion Matrix

# %%
print(confusion_matrix(y_test, predictions))
# Out:
# [[488   0   2]
#  [  2  43   7]
#  [ 29   3  64]]

# %%
ax= plt.subplot()
sns.heatmap(confusion_matrix(y_test, predictions), annot=True, ax = ax, cmap = "BuPu");

# labels, title and ticks
ax.set_xlabel("Predicted labels")
ax.set_ylabel("True labels")
ax.set_title("Confusion Matrix")
ax.xaxis.set_ticklabels(["Normal", "Suspect", "Pathological"])
# Out:
# [Text(0.5, 0, 'Normal'), Text(1.5, 0, 'Suspect'), Text(2.5, 0, 'Pathological')]

# %% [markdown]
# ### Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb = GradientBoostingClassifier(n_estimators=500, max_features=2, random_state = 42)
gb.fit(X_train, y_train)
gb_pred = gb.predict(X_test)

#Model evaluation

f1 = f1_score(y_test, gb_pred, average='weighted')
ac = accuracy_score(y_test, gb_pred, normalize=True)
recall = recall_score(y_test, gb_pred, average="weighted")
precision = precision_score(y_test, gb_pred, average="weighted")

print("********* Gradient Boosting Results *********")
print("Accuracy    : ", ac)
print("Recall      : ", recall)
print("Precision   : ", precision)
print("F1 Score    : ", f1)
# Out:
# ********* Gradient Boosting Results *********
# Accuracy    :  0.9435736677115988
# Recall      :  0.9435736677115988
# Precision   :  0.9420287700249523
# F1 Score    :  0.9413399363906463

# %% [markdown]
# #### Classification Report

# %%
print(classification_report(y_test, gb_pred))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.95      0.99      0.97       490
# Pathological       0.92      0.88      0.90        52
#      Suspect       0.90      0.74      0.81        96
#
#     accuracy                           0.94       638
#    macro avg       0.92      0.87      0.89       638
# weighted avg       0.94      0.94      0.94       638

# %% [markdown]
# #### Confusion Matrix

# %%
print(confusion_matrix(y_test, gb_pred))
# Out:
# [[485   1   4]
#  [  2  46   4]
#  [ 22   3  71]]

# %%
ax= plt.subplot()
sns.heatmap(confusion_matrix(y_test, gb_pred), annot=True, ax = ax, cmap = "BuPu");

# labels, title and ticks
ax.set_xlabel("Predicted labels")
ax.set_ylabel("True labels")
ax.set_title("Confusion Matrix")
ax.xaxis.set_ticklabels(["Normal", "Suspect", "Pathological"])
# Out:
# [Text(0.5, 0, 'Normal'), Text(1.5, 0, 'Suspect'), Text(2.5, 0, 'Pathological')]

# %% [markdown]
# ##### Testing multiple learning rates

# %%
learning_rates = [0.05, 0.1, 0.25, 0.5, 0.75 ,1]

for learning_rate in learning_rates:
    gb = GradientBoostingClassifier(n_estimators=500, learning_rate=learning_rate, max_features=2, random_state = 0)
    gb.fit(X_train, y_train)
    
    print("Learning rate: ", learning_rate)
    print("Accuracy score (training): {0:.3f}".format(gb.score(X_train, y_train)))
    print("Accuracy score (validation): {0:.3f}".format(gb.score(X_test, y_test)))
    print()
# Out:
# Learning rate:  0.05
# Accuracy score (training): 0.999
# Accuracy score (validation): 0.942
#
# Learning rate:  0.1
# Accuracy score (training): 0.999
# Accuracy score (validation): 0.947
#
# Learning rate:  0.25
# Accuracy score (training): 0.999
# Accuracy score (validation): 0.955
#
# Learning rate:  0.5
# Accuracy score (training): 0.999
# Accuracy score (validation): 0.948
#
# Learning rate:  0.75
# Accuracy score (training): 0.999
# Accuracy score (validation): 0.948
#
# Learning rate:  1
# Accuracy score (training): 0.999
# Accuracy score (validation): 0.950

# %% [markdown]
# ##### Apply the best learning rate to the model fit and predict on testing set

# %%
gb2 = GradientBoostingClassifier(n_estimators=500, learning_rate=0.25, max_features=2, random_state = 0)
gb2.fit(X_train, y_train)
gb2_predict = gb2.predict(X_test)

#Model evaluation

f1 = f1_score(y_test, gb2_predict, average='weighted')
ac = accuracy_score(y_test, gb2_predict, normalize=True)
recall = recall_score(y_test, gb2_predict, average="weighted")
precision = precision_score(y_test, gb2_predict, average="weighted")

print("********* Gradient Boosting Results *********")
print("Accuracy    : ", ac)
print("Recall      : ", recall)
print("Precision   : ", precision)
print("F1 Score    : ", f1)
# Out:
# ********* Gradient Boosting Results *********
# Accuracy    :  0.9545454545454546
# Recall      :  0.9545454545454546
# Precision   :  0.9537670651001182
# F1 Score    :  0.9532077463548505

# %% [markdown]
# #### Confusion Matrix and Classification Report

# %%
print("Confusion Matrix:")
print(confusion_matrix(y_test, gb2_predict))

print("Classification Report")
print(classification_report(y_test, gb2_predict))
# Out:
# Confusion Matrix:
# [[485   1   4]
#  [  2  48   2]
#  [ 17   3  76]]
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.96      0.99      0.98       490
# Pathological       0.92      0.92      0.92        52
#      Suspect       0.93      0.79      0.85        96
#
#     accuracy                           0.95       638
#    macro avg       0.94      0.90      0.92       638
# weighted avg       0.95      0.95      0.95       638

# %% [markdown]
# ## Final Results

# %% [markdown]
# As we compare all the models together, Gradient Boosting model is the most accuracy with 95%.
